# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
from config import api_key
from config import gkey
from datetime import datetime
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + api_key
from scipy.stats import linregress
import gmaps

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
#for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    #if (i % 50 == 0 and i >= 50):
        #set_count += 1
        #record_count = 1
    # Create endpoint URL with each city.
    #city_url = url + "&q=" + cities[i].replace(" ","+")
    #
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_des = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_des})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | luderitz
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | kaeo
# Processing Record 8 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 1 | buala
# Processing Record 10 of Set 1 | mocuba
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | ontario
# Processing Record 13 of Set 1 | husavik
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | sharlyk
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | shingu
# Processing Record 20 of Set 1 | provideniya
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | padang
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | hay river
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | victoria
# Processing Record 36 of Set 1 | dzhebariki-khaya
# Processing Record 37 of Set 1 | olafsvik
# Processing Record 38 of Set 1 | yarmouth
# Processing Record 39 of Set 1 | korla
# Processing Record 40 of Set 1 | bambous virieux
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | toledo
# Processing Record 43 of Set 1 | vestmanna
# Processing Record 44 of Set 1 | cayenne
# Processing Record 45 of Set 1 | rio claro
# Processing Record 46 of Set 1 | ventspils
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | banda aceh
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | ruwi
# Processing Record 1 of Set 2 | brown deer
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | srednekolymsk
# Processing Record 4 of Set 2 | huangnihe
# Processing Record 5 of Set 2 | vostok
# Processing Record 6 of Set 2 | mirnyy
# Processing Record 7 of Set 2 | bagotville
# Processing Record 8 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | saint george
# Processing Record 12 of Set 2 | gushikawa
# Processing Record 13 of Set 2 | kindersley
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | nadym
# Processing Record 16 of Set 2 | tarko-sale
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | scottsbluff
# Processing Record 19 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | lata
# Processing Record 22 of Set 2 | necochea
# Processing Record 23 of Set 2 | maniitsoq
# Processing Record 24 of Set 2 | matara
# Processing Record 25 of Set 2 | havre
# Processing Record 26 of Set 2 | sabha
# Processing Record 27 of Set 2 | evensk
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | tessalit
# Processing Record 30 of Set 2 | goderich
# Processing Record 31 of Set 2 | san fernando
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | leningradskiy
# Processing Record 35 of Set 2 | walvis bay
# Processing Record 36 of Set 2 | spirit river
# Processing Record 37 of Set 2 | aykhal
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | cassilandia
# Processing Record 40 of Set 2 | ucluelet
# Processing Record 41 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 2 | lubango
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | kijang
# Processing Record 45 of Set 2 | ulladulla
# Processing Record 46 of Set 2 | kuching
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | zhigansk
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | malakal
# Processing Record 1 of Set 3 | coahuayana
# Processing Record 2 of Set 3 | mount gambier
# Processing Record 3 of Set 3 | kavaratti
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | waipawa
# Processing Record 6 of Set 3 | pareora
# Processing Record 7 of Set 3 | port hedland
# Processing Record 8 of Set 3 | lompoc
# Processing Record 9 of Set 3 | boyuibe
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | alberton
# Processing Record 13 of Set 3 | ottumwa
# Processing Record 14 of Set 3 | acarau
# Processing Record 15 of Set 3 | doha
# Processing Record 16 of Set 3 | pangai
# Processing Record 17 of Set 3 | bethel
# Processing Record 18 of Set 3 | manzhouli
# Processing Record 19 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 3 | auka
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | saint-pierre
# Processing Record 24 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 3 | baykit
# Processing Record 26 of Set 3 | avera
# Processing Record 27 of Set 3 | batagay-alyta
# Processing Record 28 of Set 3 | forest hills
# Processing Record 29 of Set 3 | vestmannaeyjar
# Processing Record 30 of Set 3 | suksun
# Processing Record 31 of Set 3 | pavlohrad
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | shache
# Processing Record 34 of Set 3 | ancud
# Processing Record 35 of Set 3 | east london
# Processing Record 36 of Set 3 | muros
# Processing Record 37 of Set 3 | vardo
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | beringovskiy
# Processing Record 40 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 41 of Set 3 | solsvik
# City not found. Skipping...
# Processing Record 42 of Set 3 | brewster
# Processing Record 43 of Set 3 | faanui
# Processing Record 44 of Set 3 | itarema
# Processing Record 45 of Set 3 | acapulco
# Processing Record 46 of Set 3 | tuatapere
# Processing Record 47 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 3 | alice springs
# Processing Record 49 of Set 3 | milicz
# Processing Record 50 of Set 3 | puerto ayora
# Processing Record 1 of Set 4 | suhbaatar
# Processing Record 2 of Set 4 | ixtapa
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 4 | port elizabeth
# Processing Record 6 of Set 4 | shelburne
# Processing Record 7 of Set 4 | chuy
# Processing Record 8 of Set 4 | new norfolk
# Processing Record 9 of Set 4 | esperance
# Processing Record 10 of Set 4 | meulaboh
# Processing Record 11 of Set 4 | klaksvik
# Processing Record 12 of Set 4 | povenets
# Processing Record 13 of Set 4 | sorland
# Processing Record 14 of Set 4 | mizdah
# Processing Record 15 of Set 4 | calabozo
# Processing Record 16 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 4 | yusva
# City not found. Skipping...
# Processing Record 18 of Set 4 | los llanos de aridane
# Processing Record 19 of Set 4 | paamiut
# Processing Record 20 of Set 4 | longyearbyen
# Processing Record 21 of Set 4 | burkhala
# City not found. Skipping...
# Processing Record 22 of Set 4 | poli
# Processing Record 23 of Set 4 | yerbogachen
# Processing Record 24 of Set 4 | ayagoz
# Processing Record 25 of Set 4 | rocha
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | havelock
# Processing Record 28 of Set 4 | alta floresta
# Processing Record 29 of Set 4 | turtas
# Processing Record 30 of Set 4 | ust-omchug
# Processing Record 31 of Set 4 | gambela
# Processing Record 32 of Set 4 | norman wells
# Processing Record 33 of Set 4 | georgetown
# Processing Record 34 of Set 4 | dutlwe
# Processing Record 35 of Set 4 | beyneu
# Processing Record 36 of Set 4 | kathu
# Processing Record 37 of Set 4 | holoby
# Processing Record 38 of Set 4 | oyotun
# Processing Record 39 of Set 4 | bilma
# Processing Record 40 of Set 4 | san jose
# Processing Record 41 of Set 4 | ukiah
# Processing Record 42 of Set 4 | filadelfia
# Processing Record 43 of Set 4 | kundiawa
# Processing Record 44 of Set 4 | alofi
# Processing Record 45 of Set 4 | raga
# Processing Record 46 of Set 4 | fortuna
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | souillac
# Processing Record 49 of Set 4 | pitsunda
# Processing Record 50 of Set 4 | kabale
# Processing Record 1 of Set 5 | turukhansk
# Processing Record 2 of Set 5 | saldanha
# Processing Record 3 of Set 5 | hovd
# Processing Record 4 of Set 5 | sao domingos do maranhao
# Processing Record 5 of Set 5 | hasaki
# Processing Record 6 of Set 5 | rudkobing
# Processing Record 7 of Set 5 | severo-kurilsk
# Processing Record 8 of Set 5 | rundu
# Processing Record 9 of Set 5 | altay
# Processing Record 10 of Set 5 | clyde river
# Processing Record 11 of Set 5 | yellowknife
# Processing Record 12 of Set 5 | port lincoln
# Processing Record 13 of Set 5 | zyryanka
# Processing Record 14 of Set 5 | havre-saint-pierre
# Processing Record 15 of Set 5 | jamestown
# Processing Record 16 of Set 5 | butembo
# Processing Record 17 of Set 5 | iqaluit
# Processing Record 18 of Set 5 | henties bay
# Processing Record 19 of Set 5 | vila velha
# Processing Record 20 of Set 5 | coihaique
# Processing Record 21 of Set 5 | grand island
# Processing Record 22 of Set 5 | aracati
# Processing Record 23 of Set 5 | isangel
# Processing Record 24 of Set 5 | ponta do sol
# Processing Record 25 of Set 5 | sakaiminato
# Processing Record 26 of Set 5 | sambava
# Processing Record 27 of Set 5 | carnarvon
# Processing Record 28 of Set 5 | ilulissat
# Processing Record 29 of Set 5 | altamont
# Processing Record 30 of Set 5 | nemuro
# Processing Record 31 of Set 5 | labuhan
# Processing Record 32 of Set 5 | ahipara
# Processing Record 33 of Set 5 | adre
# Processing Record 34 of Set 5 | omboue
# Processing Record 35 of Set 5 | abnub
# Processing Record 36 of Set 5 | pytalovo
# Processing Record 37 of Set 5 | dikson
# Processing Record 38 of Set 5 | hofn
# Processing Record 39 of Set 5 | yulara
# Processing Record 40 of Set 5 | banmankhi
# Processing Record 41 of Set 5 | mtama
# Processing Record 42 of Set 5 | namatanai
# Processing Record 43 of Set 5 | iwaki
# Processing Record 44 of Set 5 | cabo san lucas
# Processing Record 45 of Set 5 | half moon bay
# Processing Record 46 of Set 5 | luwuk
# Processing Record 47 of Set 5 | bertea
# Processing Record 48 of Set 5 | gizo
# Processing Record 49 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 5 | bogande
# Processing Record 1 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 6 | xichang
# Processing Record 4 of Set 6 | viedma
# Processing Record 5 of Set 6 | tanggu
# Processing Record 6 of Set 6 | tautira
# Processing Record 7 of Set 6 | bandarbeyla
# Processing Record 8 of Set 6 | andenes
# Processing Record 9 of Set 6 | lebu
# Processing Record 10 of Set 6 | whitehorse
# Processing Record 11 of Set 6 | palmer
# Processing Record 12 of Set 6 | soure
# Processing Record 13 of Set 6 | sembe
# Processing Record 14 of Set 6 | constitucion
# Processing Record 15 of Set 6 | kalmunai
# Processing Record 16 of Set 6 | fairbanks
# Processing Record 17 of Set 6 | tucumcari
# Processing Record 18 of Set 6 | kropotkin
# Processing Record 19 of Set 6 | san carlos de bariloche
# Processing Record 20 of Set 6 | petropavl
# Processing Record 21 of Set 6 | fort nelson
# Processing Record 22 of Set 6 | shimoda
# Processing Record 23 of Set 6 | ushtobe
# Processing Record 24 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 25 of Set 6 | tatawin
# Processing Record 26 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 27 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 6 | bengkulu
# Processing Record 29 of Set 6 | pangkalanbuun
# Processing Record 30 of Set 6 | paka
# Processing Record 31 of Set 6 | barentu
# Processing Record 32 of Set 6 | maragogi
# Processing Record 33 of Set 6 | isla mujeres
# Processing Record 34 of Set 6 | mareeba
# Processing Record 35 of Set 6 | poum
# Processing Record 36 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 6 | codrington
# Processing Record 38 of Set 6 | samarai
# Processing Record 39 of Set 6 | bam
# Processing Record 40 of Set 6 | lorengau
# Processing Record 41 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 6 | augusto correa
# Processing Record 43 of Set 6 | san patricio
# Processing Record 44 of Set 6 | portel
# Processing Record 45 of Set 6 | anadyr
# Processing Record 46 of Set 6 | jos
# Processing Record 47 of Set 6 | nanortalik
# Processing Record 48 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 6 | cidreira
# Processing Record 50 of Set 6 | kraslava
# Processing Record 1 of Set 7 | rawson
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | iwanai
# Processing Record 4 of Set 7 | vila franca do campo
# Processing Record 5 of Set 7 | vigrestad
# Processing Record 6 of Set 7 | praia da vitoria
# Processing Record 7 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 8 of Set 7 | voh
# Processing Record 9 of Set 7 | khani
# Processing Record 10 of Set 7 | kulunda
# Processing Record 11 of Set 7 | nelson bay
# Processing Record 12 of Set 7 | vuktyl
# Processing Record 13 of Set 7 | northam
# Processing Record 14 of Set 7 | batavia
# Processing Record 15 of Set 7 | tabas
# Processing Record 16 of Set 7 | breves
# Processing Record 17 of Set 7 | birobidzhan
# Processing Record 18 of Set 7 | pisco
# Processing Record 19 of Set 7 | cam ranh
# Processing Record 20 of Set 7 | la ronge
# Processing Record 21 of Set 7 | rampura
# Processing Record 22 of Set 7 | salvador
# Processing Record 23 of Set 7 | inirida
# Processing Record 24 of Set 7 | mayo
# Processing Record 25 of Set 7 | saurimo
# Processing Record 26 of Set 7 | othonoi
# City not found. Skipping...
# Processing Record 27 of Set 7 | airai
# Processing Record 28 of Set 7 | marsh harbour
# Processing Record 29 of Set 7 | phalodi
# Processing Record 30 of Set 7 | mountain home
# Processing Record 31 of Set 7 | torbay
# Processing Record 32 of Set 7 | charlestown
# Processing Record 33 of Set 7 | bani walid
# Processing Record 34 of Set 7 | gijon
# Processing Record 35 of Set 7 | karratha
# Processing Record 36 of Set 7 | terenos
# Processing Record 37 of Set 7 | cherskiy
# Processing Record 38 of Set 7 | benguela
# Processing Record 39 of Set 7 | zhaocheng
# City not found. Skipping...
# Processing Record 40 of Set 7 | faya
# Processing Record 41 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 7 | kaka
# Processing Record 43 of Set 7 | kataysk
# Processing Record 44 of Set 7 | iznoski
# Processing Record 45 of Set 7 | burns lake
# Processing Record 46 of Set 7 | toppenish
# Processing Record 47 of Set 7 | biltine
# Processing Record 48 of Set 7 | dingle
# Processing Record 49 of Set 7 | polson
# Processing Record 50 of Set 7 | estreito
# Processing Record 1 of Set 8 | raudeberg
# Processing Record 2 of Set 8 | bilibino
# Processing Record 3 of Set 8 | monrovia
# Processing Record 4 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 8 | diamantino
# Processing Record 6 of Set 8 | mitsamiouli
# Processing Record 7 of Set 8 | yar-sale
# Processing Record 8 of Set 8 | taltal
# Processing Record 9 of Set 8 | marshall
# Processing Record 10 of Set 8 | lumby
# Processing Record 11 of Set 8 | port hardy
# Processing Record 12 of Set 8 | shostka
# Processing Record 13 of Set 8 | yayva
# Processing Record 14 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 15 of Set 8 | tilichiki
# Processing Record 16 of Set 8 | nuevo laredo
# Processing Record 17 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 8 | waitati
# Processing Record 19 of Set 8 | grindavik
# Processing Record 20 of Set 8 | baracoa
# Processing Record 21 of Set 8 | kholodnyy
# Processing Record 22 of Set 8 | rio gallegos
# Processing Record 23 of Set 8 | meridian
# Processing Record 24 of Set 8 | laguna
# Processing Record 25 of Set 8 | sao joao da barra
# Processing Record 26 of Set 8 | nouadhibou
# Processing Record 27 of Set 8 | lagoa
# Processing Record 28 of Set 8 | durango
# Processing Record 29 of Set 8 | cabedelo
# Processing Record 30 of Set 8 | mount isa
# Processing Record 31 of Set 8 | san cristobal
# Processing Record 32 of Set 8 | thompson
# Processing Record 33 of Set 8 | yefimovskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | moose factory
# Processing Record 35 of Set 8 | manicore
# Processing Record 36 of Set 8 | itoman
# Processing Record 37 of Set 8 | jacareacanga
# Processing Record 38 of Set 8 | ranong
# Processing Record 39 of Set 8 | sinnar
# Processing Record 40 of Set 8 | ugoofaaru
# Processing Record 41 of Set 8 | ewo
# Processing Record 42 of Set 8 | vitim
# Processing Record 43 of Set 8 | ulmeni
# Processing Record 44 of Set 8 | wuchang
# Processing Record 45 of Set 8 | cotacachi
# Processing Record 46 of Set 8 | cairns
# Processing Record 47 of Set 8 | riyadh
# Processing Record 48 of Set 8 | narok
# Processing Record 49 of Set 8 | krasnoselkup
# Processing Record 50 of Set 8 | farrukhnagar
# Processing Record 1 of Set 9 | saint-joseph
# Processing Record 2 of Set 9 | leh
# Processing Record 3 of Set 9 | sinnamary
# Processing Record 4 of Set 9 | sioux lookout
# Processing Record 5 of Set 9 | gat
# Processing Record 6 of Set 9 | santa cruz
# Processing Record 7 of Set 9 | wesseling
# Processing Record 8 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 9 | honningsvag
# Processing Record 10 of Set 9 | kahului
# Processing Record 11 of Set 9 | mazarron
# Processing Record 12 of Set 9 | monte patria
# Processing Record 13 of Set 9 | adelaide
# Processing Record 14 of Set 9 | yining
# Processing Record 15 of Set 9 | natal
# Processing Record 16 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 9 | richards bay
# Processing Record 18 of Set 9 | seoul
# Processing Record 19 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 9 | eureka
# Processing Record 21 of Set 9 | cumbal
# Processing Record 22 of Set 9 | madzhalis
# Processing Record 23 of Set 9 | naval
# Processing Record 24 of Set 9 | saravena
# Processing Record 25 of Set 9 | humaita
# Processing Record 26 of Set 9 | piacabucu
# Processing Record 27 of Set 9 | sao jose da coroa grande
# Processing Record 28 of Set 9 | cockburn town
# Processing Record 29 of Set 9 | sobolevo
# Processing Record 30 of Set 9 | lomovka
# Processing Record 31 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 32 of Set 9 | mantua
# Processing Record 33 of Set 9 | nome
# Processing Record 34 of Set 9 | ostrovnoy
# Processing Record 35 of Set 9 | nabire
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | llanes
# Processing Record 38 of Set 9 | lac du bonnet
# Processing Record 39 of Set 9 | alot
# Processing Record 40 of Set 9 | tucupita
# Processing Record 41 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 9 | agadir
# Processing Record 43 of Set 9 | billings
# Processing Record 44 of Set 9 | bend
# Processing Record 45 of Set 9 | oranjemund
# Processing Record 46 of Set 9 | salalah
# Processing Record 47 of Set 9 | capari
# Processing Record 48 of Set 9 | skibbereen
# Processing Record 49 of Set 9 | carupano
# Processing Record 50 of Set 9 | touros
# Processing Record 1 of Set 10 | marquard
# Processing Record 2 of Set 10 | loubomo
# Processing Record 3 of Set 10 | bhongaon
# Processing Record 4 of Set 10 | nagato
# Processing Record 5 of Set 10 | morant bay
# Processing Record 6 of Set 10 | yomou
# Processing Record 7 of Set 10 | mundo nuevo
# Processing Record 8 of Set 10 | aquin
# Processing Record 9 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 10 | marovoay
# Processing Record 11 of Set 10 | terrace
# Processing Record 12 of Set 10 | ishioka
# Processing Record 13 of Set 10 | luoyang
# Processing Record 14 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 15 of Set 10 | comodoro rivadavia
# Processing Record 16 of Set 10 | chekmagush
# Processing Record 17 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 18 of Set 10 | sitka
# Processing Record 19 of Set 10 | kaabong
# Processing Record 20 of Set 10 | venice
# Processing Record 21 of Set 10 | meadow lake
# Processing Record 22 of Set 10 | lubao
# Processing Record 23 of Set 10 | erdenet
# Processing Record 24 of Set 10 | lagos
# Processing Record 25 of Set 10 | haikou
# Processing Record 26 of Set 10 | lufilufi
# Processing Record 27 of Set 10 | valverde del camino
# Processing Record 28 of Set 10 | port hawkesbury
# Processing Record 29 of Set 10 | kapit
# Processing Record 30 of Set 10 | marzuq
# Processing Record 31 of Set 10 | kruisfontein
# Processing Record 32 of Set 10 | kalianget
# Processing Record 33 of Set 10 | casa grande
# Processing Record 34 of Set 10 | elko
# Processing Record 35 of Set 10 | edenderry
# Processing Record 36 of Set 10 | caravelas
# Processing Record 37 of Set 10 | verkhoyansk
# Processing Record 38 of Set 10 | port macquarie
# Processing Record 39 of Set 10 | hammerfest
# Processing Record 40 of Set 10 | makakilo city
# Processing Record 41 of Set 10 | manitouwadge
# Processing Record 42 of Set 10 | carutapera
# Processing Record 43 of Set 10 | warmbad
# Processing Record 44 of Set 10 | sumenep
# Processing Record 45 of Set 10 | qingdao
# Processing Record 46 of Set 10 | muisne
# Processing Record 47 of Set 10 | toktogul
# Processing Record 48 of Set 10 | hambantota
# Processing Record 49 of Set 10 | kant
# Processing Record 50 of Set 10 | socorro
# Processing Record 1 of Set 11 | deputatskiy
# Processing Record 2 of Set 11 | embu
# Processing Record 3 of Set 11 | soe
# Processing Record 4 of Set 11 | cap malheureux
# Processing Record 5 of Set 11 | coquimbo
# Processing Record 6 of Set 11 | prince rupert
# Processing Record 7 of Set 11 | zatoka
# Processing Record 8 of Set 11 | portsmouth
# Processing Record 9 of Set 11 | yuancheng
# Processing Record 10 of Set 11 | chachapoyas
# Processing Record 11 of Set 11 | narsaq
# Processing Record 12 of Set 11 | phayakkhaphum phisai
# Processing Record 13 of Set 11 | arman
# Processing Record 14 of Set 11 | jinka
# Processing Record 15 of Set 11 | praia
# Processing Record 16 of Set 11 | taksimo
# Processing Record 17 of Set 11 | yumbe
# Processing Record 18 of Set 11 | bathsheba
# Processing Record 19 of Set 11 | labis
# Processing Record 20 of Set 11 | santiago del estero
# Processing Record 21 of Set 11 | surgut
# Processing Record 22 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 23 of Set 11 | lagarto
# Processing Record 24 of Set 11 | parkes
# Processing Record 25 of Set 11 | kuvandyk
# Processing Record 26 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 11 | chara
# Processing Record 28 of Set 11 | watsa
# Processing Record 29 of Set 11 | sawakin
# Processing Record 30 of Set 11 | baykalovo
# Processing Record 31 of Set 11 | radis
# Processing Record 32 of Set 11 | portland
# Processing Record 33 of Set 11 | kuruman
# Processing Record 34 of Set 11 | dudinka
# Processing Record 35 of Set 11 | grand gaube
# Processing Record 36 of Set 11 | kamenka
# Processing Record 37 of Set 11 | chiredzi
# Processing Record 38 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 11 | baglung
# Processing Record 40 of Set 11 | le port
# Processing Record 41 of Set 11 | gornopravdinsk
# Processing Record 42 of Set 11 | brigantine
# Processing Record 43 of Set 11 | binzhou
# Processing Record 44 of Set 11 | novoagansk
# Processing Record 45 of Set 11 | ocos
# Processing Record 46 of Set 11 | khorixas
# Processing Record 47 of Set 11 | katsuura
# Processing Record 48 of Set 11 | borogontsy
# Processing Record 49 of Set 11 | kindu
# Processing Record 50 of Set 11 | novikovo
# Processing Record 1 of Set 12 | cururupu
# Processing Record 2 of Set 12 | olinda
# Processing Record 3 of Set 12 | ribas do rio pardo
# Processing Record 4 of Set 12 | linxia
# Processing Record 5 of Set 12 | nanakuli
# Processing Record 6 of Set 12 | hami
# Processing Record 7 of Set 12 | orbetello
# Processing Record 8 of Set 12 | mastic beach
# Processing Record 9 of Set 12 | suda
# Processing Record 10 of Set 12 | huarmey
# Processing Record 11 of Set 12 | karasjok
# Processing Record 12 of Set 12 | kayanga
# Processing Record 13 of Set 12 | sasayama
# Processing Record 14 of Set 12 | kyren
# Processing Record 15 of Set 12 | creston
# Processing Record 16 of Set 12 | floro
# Processing Record 17 of Set 12 | frontera
# Processing Record 18 of Set 12 | polyarnyy
# Processing Record 19 of Set 12 | landeck
# Processing Record 20 of Set 12 | akyab
# Processing Record 21 of Set 12 | belmonte
# Processing Record 22 of Set 12 | vanavara
# Processing Record 23 of Set 12 | boyolangu
# Processing Record 24 of Set 12 | am timan
# Processing Record 25 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 12 | chulman
# Processing Record 27 of Set 12 | pacific grove
# Processing Record 28 of Set 12 | medicine hat
# Processing Record 29 of Set 12 | aksarka
# Processing Record 30 of Set 12 | den helder
# Processing Record 31 of Set 12 | lasa
# Processing Record 32 of Set 12 | komsomolskiy
# Processing Record 33 of Set 12 | camabatela
# Processing Record 34 of Set 12 | buchanan
# Processing Record 35 of Set 12 | buraydah
# Processing Record 36 of Set 12 | okhotsk
# Processing Record 37 of Set 12 | galveston
# Processing Record 38 of Set 12 | zhezkazgan
# Processing Record 39 of Set 12 | luau
# Processing Record 40 of Set 12 | aksu
# Processing Record 41 of Set 12 | vila
# Processing Record 42 of Set 12 | champerico
# Processing Record 43 of Set 12 | alyangula
# Processing Record 44 of Set 12 | teneguiban
# City not found. Skipping...
# Processing Record 45 of Set 12 | sohag
# Processing Record 46 of Set 12 | naze
# Processing Record 47 of Set 12 | high prairie
# Processing Record 48 of Set 12 | axim
# Processing Record 49 of Set 12 | wamba
# Processing Record 50 of Set 12 | rurrenabaque
# Processing Record 1 of Set 13 | saint-francois
# Processing Record 2 of Set 13 | sulangan
# Processing Record 3 of Set 13 | loukhi
# Processing Record 4 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 5 of Set 13 | potgietersrus
# City not found. Skipping...
# Processing Record 6 of Set 13 | xining
# Processing Record 7 of Set 13 | beloha
# Processing Record 8 of Set 13 | uray
# Processing Record 9 of Set 13 | sabang
# Processing Record 10 of Set 13 | lavrentiya
# Processing Record 11 of Set 13 | tocopilla
# Processing Record 12 of Set 13 | anastacio
# Processing Record 13 of Set 13 | price
# Processing Record 14 of Set 13 | sedan
# Processing Record 15 of Set 13 | bouna
# Processing Record 16 of Set 13 | paraiso
# Processing Record 17 of Set 13 | kalemie
# Processing Record 18 of Set 13 | bandar
# Processing Record 19 of Set 13 | san rafael
# Processing Record 20 of Set 13 | taoudenni
# Processing Record 21 of Set 13 | semey
# Processing Record 22 of Set 13 | bosaso
# Processing Record 23 of Set 13 | toamasina
# Processing Record 24 of Set 13 | general roca
# Processing Record 25 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 26 of Set 13 | kempsey
# Processing Record 27 of Set 13 | chikoy
# City not found. Skipping...
# Processing Record 28 of Set 13 | ambilobe
# Processing Record 29 of Set 13 | coracora
# Processing Record 30 of Set 13 | westport
# Processing Record 31 of Set 13 | ola
# Processing Record 32 of Set 13 | high rock
# Processing Record 33 of Set 13 | moussoro
# Processing Record 34 of Set 13 | trat
# Processing Record 35 of Set 13 | palembang
# Processing Record 36 of Set 13 | vieste
# Processing Record 37 of Set 13 | pasco
# Processing Record 38 of Set 13 | jinchang
# Processing Record 39 of Set 13 | vallenar
# Processing Record 40 of Set 13 | bassila
# Processing Record 41 of Set 13 | matamoros
# Processing Record 42 of Set 13 | suao
# City not found. Skipping...
# Processing Record 43 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 13 | khilok
# Processing Record 45 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 46 of Set 13 | ivybridge
# Processing Record 47 of Set 13 | basoko
# Processing Record 48 of Set 13 | salinopolis
# Processing Record 49 of Set 13 | emerald
# Processing Record 50 of Set 13 | ayan
# Processing Record 1 of Set 14 | abha
# Processing Record 2 of Set 14 | guaraniacu
# Processing Record 3 of Set 14 | pangnirtung
# Processing Record 4 of Set 14 | bayanday
# Processing Record 5 of Set 14 | la ciotat
# Processing Record 6 of Set 14 | igarka
# Processing Record 7 of Set 14 | colinas
# Processing Record 8 of Set 14 | aklavik
# Processing Record 9 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 10 of Set 14 | auki
# Processing Record 11 of Set 14 | bukachacha
# Processing Record 12 of Set 14 | skwierzyna
# Processing Record 13 of Set 14 | nsanje
# Processing Record 14 of Set 14 | vondrozo
# Processing Record 15 of Set 14 | killybegs
# Processing Record 16 of Set 14 | aksehir
# Processing Record 17 of Set 14 | amos
# Processing Record 18 of Set 14 | storforshei
# Processing Record 19 of Set 14 | carbondale
# Processing Record 20 of Set 14 | ternate
# Processing Record 21 of Set 14 | margate
# Processing Record 22 of Set 14 | tiksi
# Processing Record 23 of Set 14 | huanren
# Processing Record 24 of Set 14 | najran
# Processing Record 25 of Set 14 | udachnyy
# Processing Record 26 of Set 14 | coos bay
# Processing Record 27 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 14 | berlevag
# Processing Record 29 of Set 14 | te anau
# Processing Record 30 of Set 14 | chino valley
# Processing Record 31 of Set 14 | borlange
# City not found. Skipping...
# Processing Record 32 of Set 14 | qunduz
# Processing Record 33 of Set 14 | rognan
# Processing Record 34 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 14 | soller
# Processing Record 37 of Set 14 | banjar
# Processing Record 38 of Set 14 | zanesville
# Processing Record 39 of Set 14 | ryotsu
# Processing Record 40 of Set 14 | marawi
# Processing Record 41 of Set 14 | celestun
# Processing Record 42 of Set 14 | benjamin hill
# Processing Record 43 of Set 14 | thinadhoo
# Processing Record 44 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 45 of Set 14 | markala
# Processing Record 46 of Set 14 | husum
# Processing Record 47 of Set 14 | kununurra
# Processing Record 48 of Set 14 | hervey bay
# Processing Record 49 of Set 14 | perugia
# Processing Record 50 of Set 14 | talaya
# Processing Record 1 of Set 15 | teya
# Processing Record 2 of Set 15 | nevinnomyssk
# Processing Record 3 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 4 of Set 15 | russas
# Processing Record 5 of Set 15 | pudozh
# Processing Record 6 of Set 15 | prainha
# Processing Record 7 of Set 15 | broken hill
# Processing Record 8 of Set 15 | ketchikan
# Processing Record 9 of Set 15 | zhangye
# Processing Record 10 of Set 15 | guarapari
# Processing Record 11 of Set 15 | dali
# Processing Record 12 of Set 15 | genhe
# Processing Record 13 of Set 15 | ngunguru
# Processing Record 14 of Set 15 | yei
# Processing Record 15 of Set 15 | vao
# Processing Record 16 of Set 15 | san buenaventura
# Processing Record 17 of Set 15 | kabwe
# Processing Record 18 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 15 | ajaccio
# Processing Record 20 of Set 15 | miraflores
# Processing Record 21 of Set 15 | nioro
# Processing Record 22 of Set 15 | saulkrasti
# Processing Record 23 of Set 15 | junqueiro
# Processing Record 24 of Set 15 | benha
# City not found. Skipping...
# Processing Record 25 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 15 | ariquemes
# Processing Record 27 of Set 15 | katherine
# Processing Record 28 of Set 15 | kirovskiy
# Processing Record 29 of Set 15 | tlyarota
# City not found. Skipping...
# Processing Record 30 of Set 15 | rehoboth
# Processing Record 31 of Set 15 | yanji
# Processing Record 32 of Set 15 | tchaourou
# Processing Record 33 of Set 15 | lakki marwat
# Processing Record 34 of Set 15 | gweta
# Processing Record 35 of Set 15 | suntar
# Processing Record 36 of Set 15 | purpe
# Processing Record 37 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 15 | araouane
# Processing Record 39 of Set 15 | alamogordo
# Processing Record 40 of Set 15 | rafai
# Processing Record 41 of Set 15 | vangaindrano
# Processing Record 42 of Set 15 | sao filipe
# Processing Record 43 of Set 15 | solnechnyy
# Processing Record 44 of Set 15 | isiro
# Processing Record 45 of Set 15 | talara
# Processing Record 46 of Set 15 | rantepao
# Processing Record 47 of Set 15 | boli
# Processing Record 48 of Set 15 | charters towers
# Processing Record 49 of Set 15 | qaqortoq
# Processing Record 50 of Set 15 | oka
# Processing Record 1 of Set 16 | havoysund
# Processing Record 2 of Set 16 | giresun
# Processing Record 3 of Set 16 | santarem
# Processing Record 4 of Set 16 | seminole
# Processing Record 5 of Set 16 | skjervoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Hermanus      ZA -34.4187   19.2345     60.91        76         100
# 1      Pevek      RU  69.7008  170.3133     35.51        91          34
# 2   Luderitz      NA -26.6481   15.1594     59.76        81           1
# 3  Hithadhoo      MV  -0.6000   73.0833     82.76        73           0
# 4     Albany      US  42.6001  -73.9662     87.75        80         100
# 5       Kaeo      NZ -35.1000  173.7833     57.33        97          94
# 6      Buala      SB  -8.1450  159.5921     80.47        80          92
# 7     Mocuba      MZ -16.8392   36.9856     61.32        96           3
# 8    Ushuaia      AR -54.8000  -68.3000     46.02        81          20
# 9    Ontario      US  34.0633 -117.6509     80.26        51          20
#
#    Wind Speed Current Description
# 0        6.40     overcast clouds
# 1        6.29    scattered clouds
# 2        3.06           clear sky
# 3        9.78           clear sky
# 4        1.99       moderate rain
# 5       12.10     overcast clouds
# 6       10.27     overcast clouds
# 7        2.80           clear sky
# 8        5.75          few clouds
# 9        4.61          few clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
